# %% [markdown]
# <a href="https://colab.research.google.com/github/nisargshah95/Comparison-of-Indexes-for-PMem/blob/main/CS764.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

threads = [1, 2, 4, 8, 16]
colors = ['red', 'blue', 'green']
xlabel = 'Number of threads'
lat_ylabel = 'Latency (us)'
lat_ylabel_ns = 'Latency (ns)'
tp_ylabel = 'Throughput (million ops/sec)'
legend_prop={'size': 14}
fmt='.-'
fmt2='.--'

dash_0_tp = [1.709836,3.358718,6.219043,10.959995,14.119449]
dash_0_p50 = [236,238,257,285,405]
dash_0_p99 = [574,578,604,626,760]
dash_10_tp = [1.685789,3.273364,6.044941,10.870269,14.048054]
dash_10_p50 = [243,242,260,295,409]
dash_10_p99 = [585,599,622,640,776]
dash_50_tp = [1.336390,2.584932,4.735336,10.206920,13.487973]
dash_50_p50 = [319,334,362,372,448]
dash_50_p99 = [703,734,791,732,900]
lbtree_0_tp = [1.304693,2.550377,4.716751,8.437790, 11.691611]
lbtree_0_p50 = [431,439,468,514,640]
lbtree_0_p99 = [777,783,829,889,1035]
lbtree_10_tp = [1.266481,2.469077,4.576180,8.154686,11.386989]
lbtree_10_p50 = [442,450,481,530,658]
lbtree_10_p99 = [915,961,1024,1124,1393]
lbtree_50_tp = [1.133613,2.199229,4.110090,7.407323,10.588345]
lbtree_50_p50 = [501,515,549,607,731]
lbtree_50_p99 = [1341,1365,1455,1582,1959]
bztree_0_tp = [.953072,1.929352,3.523684,6.172321,7.980997]
bztree_0_p50 = [679,673,736,838,1138]
bztree_0_p99 = [1085,1081,1149,1319,1864]
bztree_10_tp = [.718435,1.450484,2.688624,4.656001,6.449443]
bztree_10_p50 = [701,704,760,867,1200]
bztree_10_p99 = [3544,3547,3753,4077,5052]
bztree_50_tp = [.354642,.725215,1.358797,2.484297,3.716887]
bztree_50_p50 = [2950,2916,3045,3281,3146]
bztree_50_p99 = [21086,21117,22287,24313,32311]
dash_0_l3 = [49.423820,49.299644,48.534499,47.356524,47.104781]
dash_10_l3 = [49.258510,46.933061,46.570413,48.687618,46.993465]
dash_50_l3 = [47.568189,45.486167,43.424346,49.155642,45.786084]
lbtree_0_l3 = [63.632263,63.497902,63.273993, 63.071201,61.649675]
lbtree_10_l3 = [65.311787,66.423600,65.686526,66.099274,64.751183]
lbtree_50_l3 = [68.168272,69.469445,69.139906,68.912775,67.703740]
bztree_0_l3 = [304.882450,296.274525,304.517481,316.477723,305.837922]
bztree_10_l3 = [344.967592,337.555476,344.603860,358.431694,348.364762]
bztree_50_l3 = [536.714007,519.173596,528.248164,536.339201,535.472504]

# 99.9, 99.99 and 99.999% latency tile data
dash_0_p99_9 = [.680000,.686000,.709000,.754000,.923000]
dash_0_p99_99 = [2.519000,14.957000,3.059000,15.433000,5.305000]
dash_0_p99_999 = [15.339000,16.484000,16.040000,16.914000,16.608000]
dash_10_p99_9 = [.705000,.765000,.798000,.806000,.992000]
dash_10_p99_99 = [2.523000,15.069000,15.206000,15.449000,4.638000]
dash_10_p99_999 = [15.460000,16.536000,16.361000,16.986000,16.427000]
dash_50_p99_9 = [50.288000,50.499000,52.765000,.911000,1.184000]
dash_50_p99_99 = [51.687000,52.829000,56.330000,15.761000,4.924000]
dash_50_p99_999 = [264.041000,273.798000,529.681000,17.085000,16.488000]
lbtree_0_p99_9 = [.877000,.878000,.878000,.880000,.903000]
lbtree_0_p99_99 = [4.410000,4.342000,4.348000,4.377000,4.323000]
lbtree_0_p99_999 = [15.828000,15.852000,15.860000,15.957000,15.823000]
lbtree_10_p99_9 = [1.484000,1.538000,1.648000,1.802000,2.172000]
lbtree_10_p99_99 = [4.594000,16.231000,16.371000,16.592000,8.655000]
lbtree_10_p99_999 = [16.041000,17.104000,17.099000,17.508000,17.617000]
lbtree_50_p99_9 = [1.623000,1.687000,1.782000,1.883000,2.286000]
lbtree_50_p99_99 = [5.419000,16.443000,16.526000,5.886000,8.091000]
lbtree_50_p99_999 = [16.185000,17.673000,17.500000,17.459000,17.708000]
bztree_0_p99_9 = [1.376000,1.671000,1.804000,1.901000,2.803000]
bztree_0_p99_99 = [15.986000,16.650000,16.684000,16.855000,15.573000]
bztree_0_p99_999 = [16.538000,17.259000,17.410000,20.669000,185.548000]
bztree_10_p99_9 = [22.029000,22.132000,23.325000,25.551000,34.941000]
bztree_10_p99_99 = [28.217000,28.689000,30.297000,39.598000,45.967000]
bztree_10_p99_999 = [235.072000,250.963000,306.801000,705.184000,701.119000]
bztree_50_p99_9 = [23.101000,23.394000,24.995000,26.979000,35.386000]
bztree_50_p99_99 = [49.788000,41.667000,48.042000,230.215000,418.067000]
bztree_50_p99_999 = [338.350000,2177.667000,1256.473000,746.016000,756.065000]

# %%
# READ ONLY - L3 MISSES VS THREADS (ACROSS TREES)

plt.figure()
bzReadOnlyLine, = plt.plot(threads, bztree_0_l3, fmt, color=colors[0], label = 'BzTree')
dReadOnlyLine, = plt.plot(threads, dash_0_l3, fmt, color=colors[1], label = 'Dash')
lReadOnlyLine, = plt.plot(threads, lbtree_0_l3, fmt, color=colors[2], label = 'LB-Tree')

plt.xlabel(xlabel, fontsize=12)
plt.xticks(threads)
plt.ylabel('L3 Misses (millions)', fontsize=12)
#plt.title('Read Only Workload (L3 Misses vs Threads)')
plt.grid(True, axis='y', color='lightgray', which='both')
plt.legend(handles=[bzReadOnlyLine, dReadOnlyLine, lReadOnlyLine], prop=legend_prop)

# %%
# READ ONLY - THROUGHPUT VS THREADS (ACROSS TREES)

plt.figure()
bzReadOnlyLine, = plt.plot(threads, bztree_0_tp, fmt, color=colors[0], label = 'BzTree')
dReadOnlyLine, = plt.plot(threads, dash_0_tp, fmt, color=colors[1], label = 'Dash')
lReadOnlyLine, = plt.plot(threads, lbtree_0_tp, fmt, color=colors[2], label = 'LB-Tree')

plt.xlabel(xlabel, fontsize=12)
plt.xticks(threads)
plt.ylabel(tp_ylabel, fontsize=12)
#plt.title('Read Only Workload (Throughput vs Threads)')
plt.grid(True, axis='y', color='lightgray', which='both')
plt.legend(handles=[bzReadOnlyLine, dReadOnlyLine, lReadOnlyLine], prop=legend_prop)

# %%
# 10% WRITE - THROUGHPUT VS THREADS (ACROSS TREES)

plt.figure()
bz10WriteLine, = plt.plot(threads, bztree_10_tp, fmt, color=colors[0], label = 'BzTree')
d10WriteLine, = plt.plot(threads, dash_10_tp, fmt, color=colors[1], label = 'Dash')
l10WriteLine, = plt.plot(threads, lbtree_10_tp, fmt, color=colors[2], label = 'LB-Tree')

plt.xlabel(xlabel, fontsize=12)
plt.xticks(threads)
plt.ylabel(tp_ylabel, fontsize=12)
#plt.title('10% Write Workload (Throughput vs Threads)')
plt.grid(True, axis='y', color='lightgray', which='both')
plt.legend(handles=[bz10WriteLine, d10WriteLine, l10WriteLine], prop=legend_prop)

# %%
# 50% WRITE - THROUGHPUT VS THREADS (ACROSS TREES)

plt.figure()
bz50WriteLine, = plt.plot(threads, bztree_50_tp, fmt, color=colors[0], label = 'BzTree')
d50WriteLine, = plt.plot(threads, dash_50_tp, fmt, color=colors[1], label = 'Dash')
l50WriteLine, = plt.plot(threads, lbtree_50_tp, fmt, color=colors[2], label = 'LB-Tree')

plt.xlabel(xlabel, fontsize=12)
plt.xticks(threads)
plt.ylabel(tp_ylabel, fontsize=12)
#plt.title('50% Write Workload (Throughput vs Threads )')
plt.grid(True, axis='y', color='lightgray', which='both')
plt.legend(handles=[bz50WriteLine, d50WriteLine, l50WriteLine], prop=legend_prop)

# %%
# READ ONLY - LATENCY VS THREADS (ACROSS TREES)

plt.figure()
bzMedianReadOnlyLine, = plt.plot(threads, bztree_0_p50, fmt, color = colors[0], label = 'BzTree')
dMedianReadOnlyLine, = plt.plot(threads, dash_0_p50, fmt, color = colors[1], label = 'Dash')
lReadOnlyLine, = plt.plot(threads, lbtree_0_p50, fmt, color=colors[2], label = 'LB-Tree')

#bz99LatencyReadOnlyLine, = plt.plot(threads, bztree_0_p99, fmt2, color= 'red', label = 'BzTree (P99)')
#d99LatencyReadOnlyLine, = plt.plot(threads, dash_0_p99, fmt2, color= colors[1], label = 'Dash (P99)')
#l99LatencyReadOnlyLine, = plt.plot(threads, lbtree_0_p99, fmt2, color= colors[2], label = 'LB-Tree (P99)')

plt.xlabel(xlabel, fontsize=12)
plt.xticks(threads)
plt.ylabel(lat_ylabel_ns, fontsize=12)
#plt.title('Read Only Workload (Latency vs Threads)')
plt.grid(True, axis='y', color='lightgray', which='both')
plt.legend(handles=[bzMedianReadOnlyLine, dMedianReadOnlyLine, lReadOnlyLine], prop=legend_prop)
#plt.legend(handles=[bzMedianReadOnlyLine, dMedianReadOnlyLine, bz99LatencyReadOnlyLine, d99LatencyReadOnlyLine, l99LatencyReadOnlyLine])

# %%
# 10% writes - LATENCY VS THREADS (ACROSS TREES)

plt.figure()
bzMedian10WriteLine, = plt.plot(threads, bztree_10_p50, fmt, color = colors[0], label = 'BzTree')
dMedianLatency10Write, = plt.plot(threads, dash_10_p50, fmt, color = colors[1], label = 'Dash')
lReadOnlyLine, = plt.plot(threads, lbtree_10_p50, fmt, color=colors[2], label = 'LB-Tree')

#bz99Latency10WriteLine, = plt.plot(threads, bztree_10_p99, '--', color= colors[0], label = 'BzTree (P99)')
#d99Latency10WriteLine, = plt.plot(threads, dash_10_p99, '--', color= colors[1], label = 'Dash (P99)')
#l99Latency10WriteLine, = plt.plot(threads, lbtree_10_p99, '--', color= colors[2], label = 'LB-Tree (P99)')

plt.xlabel(xlabel, fontsize=12)
plt.xticks(threads)
plt.ylabel(lat_ylabel_ns, fontsize=12)
#plt.title('10% Workload (Latency vs Threads)')
plt.grid(True, axis='y', color='lightgray', which='both')
plt.legend(handles=[bzMedian10WriteLine, dMedianLatency10Write, lReadOnlyLine], prop=legend_prop)
#plt.legend(handles=[bzMedian10WriteLine, dMedianLatency10Write, bz99Latency10WriteLine, d99Latency10WriteLine, l99Latency10WriteLine])

# %%
# 50% writes - LATENCY VS THREADS (ACROSS TREES)

plt.figure()
bzMedian50WriteLine, = plt.plot(threads, bztree_50_p50, fmt, color = colors[0], label = 'BzTree')
dMedianLatency50Write, = plt.plot(threads, dash_50_p50, fmt, color = colors[1], label = 'Dash')
lReadOnlyLine, = plt.plot(threads, lbtree_50_p50, fmt, color=colors[2], label = 'LB-Tree')

#bz99Latency50WriteLine, = plt.plot(threads, bztree_50_p99, '.--', color= colors[0], label = 'BzTree (P99)')
#d99Latency50WriteLine, = plt.plot(threads, dash_50_p99, '.--', color= colors[1], label = 'Dash (P99)')
#l99Latency50WriteLine, = plt.plot(threads, lbtree_50_p99, '.--', color= colors[2], label = 'LB-Tree (P99)')

plt.xlabel(xlabel, fontsize=12)
plt.xticks(threads)
plt.ylabel(lat_ylabel_ns, fontsize=12)
#plt.title('50% write Workload (Latency vs Threads)')
plt.grid(True, axis='y', color='lightgray', which='both')
plt.legend(handles=[bzMedian50WriteLine, dMedianLatency50Write, lReadOnlyLine], prop=legend_prop)
#plt.legend(handles=[bzMedian50WriteLine, dMedianLatency50Write, lReadOnlyLine, bz99Latency50WriteLine, d99Latency50WriteLine, l99Latency50WriteLine])

# %%
# READ ONLY - P99 LATENCY VS THREADS (ACROSS TREES)

plt.figure()
#bzMedianReadOnlyLine, = plt.plot(threads, bztree_0_p50, fmt, color = colors[0], label = 'BzTree')
#dMedianReadOnlyLine, = plt.plot(threads, dash_0_p50, fmt, color = colors[1], label = 'Dash')
#lReadOnlyLine, = plt.plot(threads, lbtree_0_p50, fmt, color=colors[2], label = 'LB-Tree')

bz99LatencyReadOnlyLine, = plt.plot(threads, bztree_0_p99, fmt, color= 'red', label = 'BzTree')
d99LatencyReadOnlyLine, = plt.plot(threads, dash_0_p99, fmt, color= colors[1], label = 'Dash')
l99LatencyReadOnlyLine, = plt.plot(threads, lbtree_0_p99, fmt, color= colors[2], label = 'LB-Tree')

plt.xlabel(xlabel, fontsize=12)
plt.xticks(threads)
plt.ylabel(lat_ylabel_ns, fontsize=12)
#plt.title('Read Only Workload (Latency vs Threads)')
plt.grid(True, axis='y', color='lightgray', which='both')
plt.legend(handles=[bz99LatencyReadOnlyLine, d99LatencyReadOnlyLine, l99LatencyReadOnlyLine], prop=legend_prop)

# %%
# 10% writes - P99 LATENCY VS THREADS (ACROSS TREES)

plt.figure()
#bzMedian10WriteLine, = plt.plot(threads, bztree_10_p50, fmt, color = colors[0], label = 'BzTree')
#dMedianLatency10Write, = plt.plot(threads, dash_10_p50, fmt, color = colors[1], label = 'Dash')
#lReadOnlyLine, = plt.plot(threads, lbtree_10_p50, fmt, color=colors[2], label = 'LB-Tree')

bz99Latency10WriteLine, = plt.plot(threads, bztree_10_p99, fmt, color= colors[0], label = 'BzTree')
d99Latency10WriteLine, = plt.plot(threads, dash_10_p99, fmt, color= colors[1], label = 'Dash')
l99Latency10WriteLine, = plt.plot(threads, lbtree_10_p99, fmt, color= colors[2], label = 'LB-Tree')

plt.xlabel(xlabel, fontsize=12)
plt.xticks(threads)
plt.ylabel(lat_ylabel_ns, fontsize=12)
#plt.title('10% Workload (Latency vs Threads)')
plt.grid(True, axis='y', color='lightgray', which='both')
plt.legend(handles=[bz99Latency10WriteLine, d99Latency10WriteLine, l99Latency10WriteLine], prop=legend_prop)

# %%
# 50% writes - P99 LATENCY VS THREADS (ACROSS TREES)

plt.figure()
#bzMedian50WriteLine, = plt.plot(threads, bztree_50_p50, fmt, color = colors[0], label = 'BzTree')
#dMedianLatency50Write, = plt.plot(threads, dash_50_p50, fmt, color = colors[1], label = 'Dash')
#lReadOnlyLine, = plt.plot(threads, lbtree_50_p50, fmt, color=colors[2], label = 'LB-Tree')

bz99Latency50WriteLine, = plt.plot(threads, bztree_50_p99, fmt, color= colors[0], label = 'BzTree')
d99Latency50WriteLine, = plt.plot(threads, dash_50_p99, fmt, color= colors[1], label = 'Dash')
l99Latency50WriteLine, = plt.plot(threads, lbtree_50_p99, fmt, color= colors[2], label = 'LB-Tree')

plt.xlabel(xlabel, fontsize=12)
plt.xticks(threads)
plt.ylabel(lat_ylabel_ns, fontsize=12)
#plt.title('50% write Workload (Latency vs Threads)')
plt.grid(True, axis='y', color='lightgray', which='both')
plt.legend(handles=[bz99Latency50WriteLine, d99Latency50WriteLine, l99Latency50WriteLine], prop=legend_prop)

# %%
# Read-only 1 thread - Latency VS %tile (ACROSS TREES)

plt.figure()

#x_labels = ['99%', '99.9%', '99.99%', '99.999%']
bzLine, = plt.plot(x_labels,
                           [bztree_0_p99[0]/1000.0, bztree_0_p99_9[0], bztree_0_p99_99[0], bztree_0_p99_999[0]],
                           fmt, color=colors[0], label = 'BzTree')
dLine, = plt.plot(x_labels,
                          [dash_0_p99[0]/1000.0, dash_0_p99_9[0], dash_0_p99_99[0], dash_0_p99_999[0]],
                          fmt, color=colors[1], label = 'Dash')
lLine, = plt.plot(x_labels,
                          [lbtree_0_p99[0]/1000.0, lbtree_0_p99_9[0], lbtree_0_p99_99[0], lbtree_0_p99_999[0]],
                          fmt, color=colors[2], label = 'LB-Tree')

plt.xlabel('Percentile latency', fontsize=12)
plt.xticks(['99%', '99.9%', '99.99%', '99.999%'])
plt.ylabel('Latency (us)', fontsize=12)
#plt.title('Read-only workload for 1 thread (Latency vs %tile)')
plt.grid(True, axis='y', color='lightgray', which='both')
plt.legend(handles=[bzLine, dLine, lLine], prop=legend_prop)

# %%
# 10% write 1 thread - Latency VS %tile (ACROSS TREES)

plt.figure()

#x_labels = ['99%', '99.9%', '99.99%', '99.999%']
bzLine, = plt.plot(x_labels,
                           [bztree_10_p99[0]/1000.0, bztree_10_p99_9[0], bztree_10_p99_99[0], bztree_10_p99_999[0]],
                           fmt, color=colors[0], label = 'BzTree')
dLine, = plt.plot(x_labels,
                          [dash_10_p99[0]/1000.0, dash_10_p99_9[0], dash_10_p99_99[0], dash_10_p99_999[0]],
                          fmt, color=colors[1], label = 'Dash')
lLine, = plt.plot(x_labels,
                          [lbtree_10_p99[0]/1000.0, lbtree_10_p99_9[0], lbtree_10_p99_99[0], lbtree_10_p99_999[0]],
                          fmt, color=colors[2], label = 'LB-Tree')

plt.xlabel('Percentile latency', fontsize=12)
plt.xticks(['99%', '99.9%', '99.99%', '99.999%'])
plt.ylabel('Latency (us)', fontsize=12)
#plt.title('10% write workload for 1 thread (Latency vs %tile)')
plt.grid(True, axis='y', color='lightgray', which='both')
plt.legend(handles=[bzLine, dLine, lLine], prop=legend_prop)

# %%
# 50% write 1 thread - Latency VS %tile (ACROSS TREES)

plt.figure()

x_labels = ['99%', '99.9%', '99.99%', '99.999%']
bzLine, = plt.plot(x_labels,
                           [bztree_50_p99[0]/1000.0, bztree_50_p99_9[0], bztree_50_p99_99[0], bztree_50_p99_999[0]],
                           fmt, color=colors[0], label = 'BzTree')
dLine, = plt.plot(x_labels,
                          [dash_50_p99[0]/1000.0, dash_50_p99_9[0], dash_50_p99_99[0], dash_50_p99_999[0]],
                          fmt, color=colors[1], label = 'Dash')
lLine, = plt.plot(x_labels,
                          [lbtree_50_p99[0]/1000.0, lbtree_50_p99_9[0], lbtree_50_p99_99[0], lbtree_50_p99_999[0]],
                          fmt, color=colors[2], label = 'LB-Tree')

plt.xlabel('Percentile latency', fontsize=12)
plt.xticks(['99%', '99.9%', '99.99%', '99.999%'])
plt.ylabel('Latency (us)', fontsize=12)
#plt.title('50% write workload for 1 thread (Latency vs %tile)')
plt.grid(True, axis='y', color='lightgray', which='both')
plt.legend(handles=[bzLine, dLine, lLine], prop=legend_prop)

# %%
# BZ TREE GRAPH - THREADS VS THROUGHPUT

threads = [1, 8, 16, 32, 64]
bzThroughputReadOnly = [953072, 6172321, 7980997, 9056828, 9386497]
bzThroughput10Write = [718435, 4656001, 6449443, 7434534, 6688198]
bzThroughput50Write = [354642, 2484297, 3716887, 3399154, 1390102]
plt.figure(figsize=(10,8))
bzReadOnlyLine, = plt.plot(threads, bzThroughputReadOnly, color='g', label = 'Read Only')
bzWrite10Line, = plt.plot(threads, bzThroughput10Write, color='orange', label = '10% Write')
bzWrite50Line, = plt.plot(threads, bzThroughput50Write, color='black', label = '50% Write')
plt.xlabel('Threads')
plt.ylabel('Throughput in ops/sec')
plt.title('bzTree Benchmarking (Throughput vs Threads)')
plt.legend(handles=[bzReadOnlyLine, bzWrite10Line, bzWrite50Line])

# %%
# DASH TREE GRAPH - THREADS VS THROUGHPUT

threads = [1, 8, 16, 32, 64]
dThroughputReadOnly = [1709836, 10959995, 14119449, 15909001, 16930214]
dThroughput10Write = [1685789, 10870269, 14048054, 15873237, 16815622]
dThroughput50Write = [1336390, 10206920, 13487973, 15313687, 15973628]
plt.figure(figsize=(10,8))
dReadOnlyLine, = plt.plot(threads, dThroughputReadOnly, color='g', label = 'Read Only')
dWrite10Line, = plt.plot(threads, dThroughput10Write, color='orange', label = '10% Write')
dWrite50Line, = plt.plot(threads, dThroughput50Write, color='black', label = '50% Write')
plt.xlabel('Threads')
plt.ylabel('Throughput in ops/sec')
plt.title('dash Benchmarking (Throughput vs Threads)')
plt.legend(handles=[dReadOnlyLine, dWrite10Line, dWrite50Line])

# %%
# BZ TREE - MEDIAN LATENCY / P99 LATENCY v/s THREADS

threads = [1, 8, 16, 32, 64]
bzMedianLatencyReadOnly = [679, 838, 1138, 1315, 1639]
bzMedianLatency10Write = [701, 867, 1200, 1352, 1349]
bzMedianLatency50Write = [2950, 3281, 3146, 3109, 3044]
bz99LatencyReadOnly = [1085, 1319, 1864, 1965, 1953]
bz99Latency10Write = [3544, 4077, 5052, 5188, 5184]
bz99Latency50Write = [21086, 24313, 32311, 33427, 32618]
plt.figure(figsize=(10,8))
bzMedianReadOnlyLine, = plt.plot(threads, bzMedianLatencyReadOnly, color = 'g', label = 'Median Latency Read Only')
bzMedian10WriteLine, = plt.plot(threads, bzMedianLatency10Write, color = 'orange', label = 'Median Latency 10% Write')
bzMedian50WriteLine, = plt.plot(threads, bzMedianLatency50Write, color = 'black', label = 'Median Latency 50% Write')
bz99LatencyReadOnlyLine, = plt.plot(threads, bz99LatencyReadOnly, color= 'red', label = '99 Percentile Latency Read Only')
bz99Latency10WriteLine, = plt.plot(threads, bz99Latency10Write, color= 'blue', label = '99 Percentile Latency 10% Write')
bz99Latency50WriteLine, = plt.plot(threads, bz99Latency50Write, color= 'yellow', label = '99 Percentile Latency 50% Write')
plt.xlabel('Threads')
plt.ylabel('Latency in milliseconds')
plt.title('Median & 99 Percentile Latencies for bzTree')
plt.legend(handles = [bzMedianReadOnlyLine, bzMedian10WriteLine, bzMedian50WriteLine, bz99LatencyReadOnlyLine, bz99Latency10WriteLine, bz99Latency50WriteLine])

# %%
# DASH TREE - MEDIAN LATENCY / P99 LATENCY v/s THREADS

threads = [1, 8, 16, 32, 64]
dMedianLatencyReadOnly = [236, 285, 405, 427, 430]
dMedianLatency10Write = [243, 295, 409, 436, 439]
dMedianLatency50Write = [319, 372, 448, 531, 538]
d99LatencyReadOnly = [574, 626, 760, 788, 793]
d99Latency10Write = [585, 640, 776, 823, 820]
d99Latency50Write = [703, 732, 900, 952, 949]
plt.figure(figsize=(10,8))
dMedianReadOnlyLine, = plt.plot(threads, dMedianLatencyReadOnly, color = 'g', label = 'Median Latency Read Only')
dMedian10WriteLine, = plt.plot(threads, dMedianLatency10Write, color = 'orange', label = 'Median Latency 10% Write')
dMedian50WriteLine, = plt.plot(threads, dMedianLatency50Write, color = 'black', label = 'Median Latency 50% Write')
d99LatencyReadOnlyLine, = plt.plot(threads, d99LatencyReadOnly, color= 'red', label = '99 Percentile Latency Read Only')
d99Latency10WriteLine, = plt.plot(threads, d99Latency10Write, color= 'blue', label = '99 Percentile Latency 10% Write')
d99Latency50WriteLine, = plt.plot(threads, d99Latency50Write, color= 'yellow', label = '99 Percentile Latency 50% Write')
plt.xlabel('Threads')
plt.ylabel('Latency in milliseconds')
plt.title('Median & 99 Percentile Latencies for dash')
plt.legend(handles = [dMedianReadOnlyLine, dMedian10WriteLine, dMedian50WriteLine, d99LatencyReadOnlyLine, d99Latency10WriteLine, d99Latency50WriteLine])
